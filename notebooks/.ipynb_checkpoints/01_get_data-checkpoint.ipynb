# %% [markdown]
# # 1. Imports

# %%
from pathlib import Path
import gzip
import pandas as pd
import requests
import arrow

# %% [markdown]
# # 2. Paths and URL

# %%
astorb_url = "https://ftp.lowell.edu/pub/elgb/astorb.dat.gz"

output_path = Path("data/processed/astorb_reduced.parquet")
temp_path = Path("data/raw/astorb.dat.gz")

# %% [markdown]
# # 3. Download

# %%
response = requests.get(astorb_url)
response.raise_for_status()

temp_path.parent.mkdir(parents=True, exist_ok=True)
temp_path.write_bytes(response.content)
# Out:
# 113512085

# %% [markdown]
# O `raise_for_status()` é importante: se o servidor retornar, por exemplo, um erro HTTP, o notebook para imediatamente em vez de você acabar tentando interpretar uma página de erro como se fosse o `astorb.dat`.

# %% [markdown]
# # 4. Read the Fixed Width Format file

# %%
column_names = [
    "number",
    "name",
    "H",
    "G",
    "M",
    "omega",
    "Omega",
    "inc",
    "e",
    "a",
]

column_specs = [
    (0, 6),      # number
    (7, 25),     # name
    (42, 47),    # H
    (48, 53),    # G
    (115, 125),  # M
    (126, 136),  # omega
    (137, 147),  # Omega
    (147, 157),  # inc
    (158, 168),  # e
    (168, 181),  # a
]

# %% [markdown]
# Aqui eu faria questão de usar os índices Python correspondentes às posições do arquivo.
#
# O `astorb.dat` é um **fixed-width file**, portanto `read_fwf()` é exatamente a ferramenta apropriada:

# %%
with gzip.open(temp_path, mode="rt") as file:
    astorb = pd.read_fwf(
        file,
        colspecs=column_specs,
        names=column_names,
    )

# %% [markdown]
# # 5. Convert data types

# %%
astorb["number"] = pd.to_numeric(
    astorb["number"],
    errors="coerce",
).astype("Int64")

numeric_columns = [
    "H",
    "G",
    "M",
    "omega",
    "Omega",
    "inc",
    "e",
    "a",
]

astorb[numeric_columns] = astorb[numeric_columns].apply(
    pd.to_numeric,
    errors="coerce",
)

# %% [markdown]
# Aqui eu prefiro não especificar `float64` antecipadamente no `read_fwf()`. Primeiro leio o arquivo e depois faço a conversão dos campos numéricos explicitamente.

# %% [markdown]
# # 6. Select and reorder columns

# %%
astorb = astorb[
    [
        "number",
        "name",
        "H",
        "G",
        "a",
        "e",
        "inc",
        "Omega",
        "omega",
        "M",
    ]
]

# %% [markdown]
# Não há necessidade de criar `astorb_raw` e `astorb_clean`. Como você está trabalhando em um notebook e não precisa preservar as duas versões, eu simplesmente transformaria o próprio DataFrame.

# %% [markdown]
# # 7. Basic validation

# %%
astorb.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1566820 entries, 0 to 1566819
# Data columns (total 10 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   number  895910 non-null   Int64
#  1   name    1566820 non-null  str
#  2   H       1566820 non-null  float64
#  3   G       1566820 non-null  float64
#  4   a       1566820 non-null  float64
#  5   e       1566820 non-null  float64
#  6   inc     1566820 non-null  float64
#  7   Omega   1566820 non-null  float64
#  8   omega   1566820 non-null  float64
#  9   M       1566820 non-null  float64
# dtypes: Int64(1), float64(8), str(1)
# memory usage: 121.0 MB

# %% [markdown]
# E, para verificar os valores ausentes:

# %%
astorb.isna().sum()
# Out:
# number    670910
# name           0
# H              0
# G              0
# a              0
# e              0
# inc            0
# Omega          0
# omega          0
# M              0
# dtype: int64

# %% [markdown]
# Também vale uma inspeção rápida:

# %%
astorb.head()
# Out:
#    number     name     H     G         a         e        inc       Omega  \
# 0       1    Ceres  3.34  0.15  2.765922  0.079751  10.587505   80.248993
# 1       2   Pallas  4.12  0.15  2.769387  0.230707  34.933695  172.887003
# 2       3     Juno  5.19  0.15  2.671013  0.255661  12.986942  169.810194
# 3       4    Vesta  3.25  0.15  2.361256  0.090227   7.143801  103.700084
# 4       5  Astraea  6.96  0.15  2.576761  0.187587   5.359799  141.448055
#
#         omega           M
# 0   73.208090  295.937548
# 1  310.985633  275.616444
# 2  247.894048  285.308714
# 3  151.440042  108.380989
# 4  359.387522  205.288315

# %%
astorb.describe()
# Out:
#               number             H             G             a             e  \
# count       895910.0  1.566820e+06  1.566820e+06  1.566820e+06  1.566820e+06
# mean        447955.5  1.759826e+01  1.501344e-01  2.963193e+00  1.588113e-01
# std    258627.084172  1.920720e+00  2.988291e-02  6.364757e+00  9.509876e-02
# min              1.0 -1.260000e+00  0.000000e+00  4.617635e-01  3.748000e-05
# 25%        223978.25  1.672000e+01  1.500000e-01  2.400069e+00  9.265636e-02
# 50%         447955.5  1.760000e+01  1.500000e-01  2.668859e+00  1.473630e-01
# 75%        671932.75  1.847000e+01  1.500000e-01  3.029280e+00  2.043221e-01
# max         895910.0  9.999000e+01  6.660000e+00  2.705611e+03  9.975172e-01
#
#                 inc         Omega         omega             M
# count  1.566820e+06  1.566820e+06  1.566820e+06  1.566820e+06
# mean   9.294357e+00  1.704496e+02  1.818317e+02  1.763537e+02
# std    6.646425e+00  1.028792e+02  1.036870e+02  1.038033e+02
# min    6.032000e-03  2.230000e-04  6.210000e-04  3.750000e-04
# 25%    4.361469e+00  8.287999e+01  9.200776e+01  8.650003e+01
# 50%    7.870960e+00  1.619062e+02  1.837492e+02  1.727245e+02
# 75%    1.267180e+01  2.564764e+02  2.714839e+02  2.660206e+02
# max    1.759751e+02  3.599999e+02  3.599998e+02  3.599997e+02

# %% [markdown]
# # 8. Export to Parquet

# %%
output_path.parent.mkdir(parents=True, exist_ok=True)

astorb.to_parquet(
    output_path,
    index=False,
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[17], line 3
#       1 output_path.parent.mkdir(parents=True, exist_ok=True)
#       2
# ----> 3 astorb.to_parquet(
#       4     output_path,
#       5     index=False,
#       6 )
#
# File ~\AppData\Local\miniconda3\envs\astro\Lib\site-packages\pandas\core\frame.py:3135, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, filesystem, **kwargs)
#    3131         >>> content = f.read()
#    3132         """
#    3133         from pandas.io.parquet import to_parquet
#    3134
# -> 3135         return to_parquet(
#    3136             self,
#    3137             path,
#    3138             engine,
#
# File ~\AppData\Local\miniconda3\envs\astro\Lib\site-packages\pandas\io\parquet.py:486, in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     484 if isinstance(partition_cols, str):
#     485     partition_cols = [partition_cols]
# --> 486 impl = get_engine(engine)
#     488 path_or_buf: FilePath | WriteBuffer[bytes] = io.BytesIO() if path is None else path
#     490 impl.write(
#     491     df,
#     492     path_or_buf,
#    (...)    498     **kwargs,
#     499 )
#
# File ~\AppData\Local\miniconda3\envs\astro\Lib\site-packages\pandas\io\parquet.py:68, in get_engine(engine)
#      65         except ImportError as err:
#      66             error_msgs += "\n - " + str(err)
# ---> 68     raise ImportError(
#      69         "Unable to find a usable engine; "
#      70         "tried using: 'pyarrow', 'fastparquet'.\n"
#      71         "A suitable version of "
#      72         "pyarrow or fastparquet is required for parquet "
#      73         "support.\n"
#      74         "Trying to import the above resulted in these errors:"
#      75         f"{error_msgs}"
#      76     )
#      78 if engine == "pyarrow":
#      79     return PyArrowImpl()
#
# ImportError: Unable to find a usable engine; tried using: 'pyarrow', 'fastparquet'.
# A suitable version of pyarrow or fastparquet is required for parquet support.
# Trying to import the above resulted in these errors:
#  - `Import pyarrow` failed. pyarrow is required for parquet support. Use pip or conda to install the pyarrow package.
#  - `Import fastparquet` failed. fastparquet is required for parquet support. Use pip or conda to install the fastparquet package.

# %%
### 9. Remove temporary file

```python
temp_path.unlink()
```
